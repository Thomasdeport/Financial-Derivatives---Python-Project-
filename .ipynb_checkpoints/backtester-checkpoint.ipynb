# %%
from market_data_loader.data_handler import *
from market_data_loader.utils import *
from european_option import *
import numpy as np

# %%
tickers = {
    "LVMH": "MC.PA",
    "Danone": "BN.PA",
    "Siemens": "SIE.DE",
    "AXA": "CS.PA",
    "Engie": "ENGI.PA",
    "Société Générale": "GLE.PA",
    "BNP Paribas": "BNP.PA",
    "L'Oréal": "OR.PA"
}
tickers.values()
# Out:
# dict_values(['MC.PA', 'BN.PA', 'SIE.DE', 'CS.PA', 'ENGI.PA', 'GLE.PA', 'BNP.PA', 'OR.PA'])

# %%
tickers = ['MC.PA', 'BN.PA', 'SIE.DE', 'CS.PA', 'ENGI.PA', 'GLE.PA', 'BNP.PA', 'OR.PA']
handler_future = OnlineDataHandler(tickers, macro_region="europe", start ="2020-04-06")
handler = OnlineDataHandler(tickers, macro_region="europe", start ="2017-04-06", end ="2018-04-06")

handler_future.load_data()
handler.load_data()

print("\nDernier bar pour Hermes :")
print(handler.get_latest_bar('MC.PA'))
print(handler_future.get_latest_bar('MC.PA'))

print("\nVariables macroéconomiques :")
print(handler.macro_data.tail())
print(handler_future.macro_data.tail())
# Out:
# - Loading market data (1Day)...
# MC.PA: 1468 obs from Yahoo Finance (2020-04-06 → 2025-12-24) [1Day]
# BN.PA: 1468 obs from Yahoo Finance (2020-04-06 → 2025-12-24) [1Day]
# SIE.DE: 1459 obs from Yahoo Finance (2020-04-06 → 2025-12-23) [1Day]
# CS.PA: 1468 obs from Yahoo Finance (2020-04-06 → 2025-12-24) [1Day]
# ENGI.PA: 1468 obs from Yahoo Finance (2020-04-06 → 2025-12-24) [1Day]
# GLE.PA: 1468 obs from Yahoo Finance (2020-04-06 → 2025-12-24) [1Day]
# BNP.PA: 1468 obs from Yahoo Finance (2020-04-06 → 2025-12-24) [1Day]
# OR.PA: 1468 obs from Yahoo Finance (2020-04-06 → 2025-12-24) [1Day]
#
# Market data successfully loaded
# Tickers: 8 | Period: 2020-04-06 → 2025-12-24
# Observations: 1468 | Timeframe: 1Day
# - Loading macroeconomic data (EUROPE)...
# [WARN] M1SUPPLY: Unable to read URL: https://fred.stlouisfed.org/graph/fredgraph.csv?id=MABMM201EZM189S Response Text [WARN] This message is too long, cannot print it entirely
# ...

# %%
plot_candlestick_with_indices(udl="MC.PA",  indices_dict =handler_future.price_all_dict, other = [])

# %%
import numpy as np
import plotly.graph_objects as go

# --- Données reconstituées ---
term_data = {
    "AXA.PA":  {"S0": 22.0,   "atm_vols": [18.0, 18.8, 19.0, 18.7, 18.5], "steep": 6.0},
    "LVMH.PA": {"S0": 262.6,  "atm_vols": [23.0, 24.0, 24.5, 24.0, 23.5], "steep": 4.0},
    "OREP.PA": {"S0": 190.3,  "atm_vols": [19.0, 19.5, 19.7, 19.6, 19.4], "steep": 5.0},
    "BNPP.PA": {"S0": 60.6,   "atm_vols": [19.0, 20.0, 20.2, 19.9, 19.5], "steep": 7.5},
    "SOGN.PA": {"S0": 44.5,   "atm_vols": [22.0, 23.0, 23.5, 23.0, 22.5], "steep": 7.5},
    "DANO.PA": {"S0": 65.5,   "atm_vols": [19.0, 19.2, 19.4, 19.3, 19.0], "steep": 2.5},
    "ENGIE.PA":{"S0": 14.1,   "atm_vols": [20.0, 20.5, 20.8, 20.7, 20.5], "steep": 5.0},
    "SIEGn.DE":{"S0": 104.5,  "atm_vols": [20.0, 20.8, 21.0, 20.8, 20.5], "steep": 5.0},
}

maturities = np.array([3, 6, 9, 12, 18])  # en mois
rel_strikes = np.array([0.9, 1.0, 1.1])   # strikes relatifs

# --- Construction des surfaces ---
for name, d in term_data.items():
    S0 = d["S0"]
    steep = d["steep"]
    atm_vols = np.array(d["atm_vols"])
    
    K_grid = rel_strikes * S0
    T_grid = maturities
    
    vol_surface = np.zeros((len(T_grid), len(K_grid)))
    for i, vol_atm in enumerate(atm_vols):
        for j, k in enumerate(rel_strikes):
            # linéaire : vol décroît de +steep/2 à -steep/2 autour de l'ATM
            adj = 0.5 * steep * (1 if k < 1 else (-1 if k > 1 else 0))
            vol_surface[i, j] = vol_atm + adj
    
    # --- Plot 3D ---
    fig = go.Figure(data=[go.Surface(
        x=K_grid, y=T_grid, z=vol_surface,
        colorscale='Viridis',
        contours={"z": {"show": True, "usecolormap": True, "highlightcolor": "lime", "project_z": True}},
    )])
    
    fig.update_layout(
        title=f"{name} - 3M-18M implied vol surface (approx. from DB tearsheet)",
        scene=dict(
            xaxis_title="Strike",
            yaxis_title="Maturity (months)",
            zaxis_title="Implied Volatility (%)",
        ),
        template="plotly_dark",
    )
    
    fig.show()

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from scipy.stats import norm


class EuropeanOption:
    """European option pricer under Black-Scholes with strategy support."""

    def __init__(self, S, K, T, r, sigma, option_type="call", derivatives=None):
        self.S = S
        self.K = np.atleast_1d(K)
        self.T = np.atleast_1d(T)
        self.r = r
        self.sigma = sigma
        self.option_type = option_type.lower()
        self.derivatives = derivatives.lower() if derivatives else None

    # === Core Black-Scholes ===

    def _d1(self, S, K, T, sigma=None):
        sigma = self.sigma if sigma is None else sigma
        return (np.log(S / K) + (self.r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))

    def _d2(self, S, K, T, sigma=None):
        sigma = self.sigma if sigma is None else sigma
        return self._d1(S, K, T, sigma) - sigma * np.sqrt(T)

    def _bs_price(self, S, K, T, option_type, sigma=None):
        sigma = self.sigma if sigma is None else sigma
        d1, d2 = self._d1(S, K, T, sigma), self._d2(S, K, T, sigma)
        if option_type == "call":
            return S * norm.cdf(d1) - K * np.exp(-self.r * T) * norm.cdf(d2)
        else:
            return K * np.exp(-self.r * T) * norm.cdf(-d2) - S * norm.cdf(-d1)

    def _greeks(self, S, K, T, option_type, sigma=None):
        """
        Retourne un dictionnaire contenant le prix et les grecs
        pour une option européenne (Black-Scholes).
        Vega et rho sont exprimés par point de 1% (division par 100),
        theta est exprimé par jour (division par 365).
        """
        sigma = self.sigma if sigma is None else sigma

        d1, d2 = self._d1(S, K, T, sigma), self._d2(S, K, T, sigma)
        pdf = norm.pdf(d1)

        if option_type == "call":
            delta = norm.cdf(d1)
            rho = K * T * np.exp(-self.r * T) * norm.cdf(d2) / 100.0
            theta = (-S * pdf * sigma / (2 * np.sqrt(T))
                     - self.r * K * np.exp(-self.r * T) * norm.cdf(d2)) / 365.0
        else:
            delta = norm.cdf(d1) - 1.0  # équivalent à -norm.cdf(-d1)
            rho = -K * T * np.exp(-self.r * T) * norm.cdf(-d2) / 100.0
            theta = (-S * pdf * sigma / (2 * np.sqrt(T))
                     + self.r * K * np.exp(-self.r * T) * norm.cdf(-d2)) / 365.0

        gamma = pdf / (S * sigma * np.sqrt(T))
        vega = S * pdf * np.sqrt(T) / 100.0  # par 1% de vol

        price = self._bs_price(S, K, T, option_type, sigma)

        return {
            "Price": price,
            "Delta": delta,
            "Gamma": gamma,
            "Vega": vega,
            "Theta": theta,
            "Rho": rho,
        }

    # === Multi-leg Strategies ===

    def _compose_strategy(self, S, T=None, sigma=None):
        """
        Agrège prix et grecs de la stratégie définie dans self.derivatives.
        Toutes les jambes partagent le même T (par défaut self.T[0]) et sigma.
        """
        strategies = {
                "straddle": (1, [
                    ("call", 0, +1),
                    ("put", 0, +1)
                ]),
            
                "strangle": (2, [
                    ("call", 1, +1),
                    ("put", 0, +1)
                ]),
            
                "bull_call_spread": (2, [
                    ("call", 0, +1),
                    ("call", 1, -1)
                ]),
            
                "bear_put_spread": (2, [
                    ("put", 0, +1),
                    ("put", 1, -1)
                ]),
            
                "collar": (2, [
                    ("put", 0, +1),      # protection
                    ("call", 1, -1),     # financement
                    ("underlying", 0, +1)  # long sous-jacent
                ]),
                
                            
                "butterfly": (3, [
                    ("call", 0, +1),
                    ("call", 1, -2),
                    ("call", 2, +1)
                ]),
            
                "iron_condor": (4, [
                    ("put", 0, +1),
                    ("put", 1, -1),
                    ("call", 2, +1),
                    ("call", 3, -1)
                ]),
            
                # === nouvelles stratégies ===
            
                # Covered call : long underlying + short call
                # → On traite 1 unité du sous-jacent comme un delta de +1 ajouté directement
                "covered_call": (1, [
                    ("call", 0, -1)
                ]),
            
                # Protective put : long underlying + long put
                "protective_put": (1, [
                    ("put", 0, +1)
                ]),
            
                # Risk reversal : long call OTM, short put OTM
                "risk_reversal": (2, [
                    ("call", 1, +1),
                    ("put", 0, -1)
                ]),
            
                # Synthetic long : long call + short put (même strike)
                "synthetic_long": (1, [
                    ("call", 0, +1),
                    ("put", 0, -1)
                ]),
            
                # Synthetic short : short call + long put (même strike)
                "synthetic_short": (1, [
                    ("call", 0, -1),
                    ("put", 0, +1)
                ]),
            
                # Ratio spreads
                "call_ratio_spread": (2, [
                    ("call", 0, +1),
                    ("call", 1, -2)
                ]),
            
                "put_ratio_spread": (2, [
                    ("put", 0, +1),
                    ("put", 1, -2)
                ]),
            
                # Calendar spreads : même strike, maturités différentes
                # Ici on utilise K[0] pour les deux jambes, mais T varie
                # On considère que l’utilisateur fournit T sous forme [T_short, T_long]
                "call_calendar_spread": (1, [
                    ("call", 0, +1),  # long maturity
                    ("call", 0, -1)   # short maturity
                ]),
            
                "put_calendar_spread": (1, [
                    ("put", 0, +1),
                    ("put", 0, -1)
                ]),
            
                # Ladders (échelles)
                "call_ladder": (3, [
                    ("call", 0, +1),
                    ("call", 1, -1),
                    ("call", 2, -1)
                ]),
            
                "put_ladder": (3, [
                    ("put", 0, +1),
                    ("put", 1, -1),
                    ("put", 2, -1)
                ]),
            
                # Seagull : long call spread + short put ou long put spread + short call
                "call_seagull": (3, [
                    ("call", 0, +1),
                    ("call", 1, -1),
                    ("put", 2, -1)
                ]),
            }


        if self.derivatives not in strategies:
            raise ValueError(f"Unknown strategy '{self.derivatives}'.")

        required, structure = strategies[self.derivatives]
        if len(self.K) < required:
            raise ValueError(
                f"Strategy '{self.derivatives}' requires {required} strikes, got {len(self.K)}."
            )

        T_leg = self.T[0] if T is None else T

        results = []
        for opt_type, k_idx, qty in structure:
            K = self.K[k_idx]
            greeks = self._greeks(S, K, T_leg, opt_type, sigma=sigma)
            # on multiplie prix et grecs par la quantité
            results.append({k: qty * v for k, v in greeks.items()})

        df = pd.DataFrame(results)
        summary = df.sum().to_dict()
        return summary

    # === Greeks + Price plotting ===

    def plot_greeks(self, x_axis: str = "S", greek_list=None, n_points: int = 50):
        """
        Trace le prix et les grecs en fonction de S, sigma ou T.
        x_axis : 'S' | 'sigma' | 'T'
        greek_list : liste des grecs à tracer en plus du prix.
        """
        if greek_list is None:
            greek_list = ["Delta", "Gamma", "Vega", "Theta", "Rho"]

        if x_axis == "S":
            x_vals = np.linspace(0.5 * self.S, 1.5 * self.S, n_points)
        elif x_axis == "sigma":
            x_vals = np.linspace(0.05, 1.0, n_points)
        elif x_axis == "T":
            x_vals = np.linspace(0.01, self.T[0] * 2, n_points)
        else:
            raise ValueError("x_axis must be one of: 'S', 'sigma', 'T'")

        data = []
        prices = []
        sigma0 = self.sigma  # pour restaurer ensuite si besoin

        for x in x_vals:
            if x_axis == "S":
                S = x
                T = self.T[0]
                sigma = sigma0
            elif x_axis == "sigma":
                S = self.S
                T = self.T[0]
                sigma = x
            elif x_axis == "T":
                S = self.S
                T = x
                sigma = sigma0

            if self.derivatives:
                summary = self._compose_strategy(S, T=T, sigma=sigma)
            else:
                summary = self._greeks(S, self.K[0], T, self.option_type, sigma=sigma)

            data.append(summary)
            prices.append(summary["Price"])

        # on ne modifie pas self.sigma durablement
        self.sigma = sigma0

        df = pd.DataFrame(data)
        df[x_axis] = x_vals
        # on s'assure que la colonne Price correspond bien à la liste prices
        df["Price"] = prices

        fig = go.Figure()

        # Prix
        fig.add_trace(
            go.Scatter(
                x=df[x_axis],
                y=df["Price"],
                mode="lines",
                name="Price",
            )
        )

        # Grecs
        for greek in greek_list:
            if greek in df.columns:
                fig.add_trace(
                    go.Scatter(
                        x=df[x_axis],
                        y=df[greek],
                        mode="lines",
                        name=greek,
                    )
                )

        fig.update_layout(
            title=f"Price and Greeks vs {x_axis.upper()} ({self.derivatives or self.option_type})",
            xaxis_title=x_axis.upper(),
            yaxis_title="Value",
            template="plotly_dark",
            legend_title="Legend",
        )

        fig.show()

# %%
# Exemple 1 : Call simple
call = EuropeanOption(S=100, K=[90, 110], T=0.001, r=0.02, sigma=0.25, derivatives="collar")
call.plot_greeks(x_axis="S")

# Exemple 2 : Straddle
straddle = EuropeanOption(S=100, K=[100], T=0.5, r=0.02, sigma=0.25, derivatives="straddle")
straddle.plot_greeks(x_axis="S")

# Exemple 3 : Bull Call Spread
spread = EuropeanOption(S=100, K=[95, 105], T=0.5, r=0.02, sigma=0.5, derivatives="bull_call_spread")
spread.plot_greeks(x_axis="S")

# %%
spread._bs_price(S = 100, K = 0.000001234, T = 1, option_type = 'call')
# Out:
# 99.99999879043483

# %%
spread._greeks(S = 100, K = 0.000001234, T = 1, option_type = 'call')
# Out:
# {'Price': 99.99999879043483,
#  'Delta': 1.0,
#  'Gamma': 1.8017663154368049e-295,
#  'Vega': 9.008831577184024e-294,
#  'Theta': -6.627754317044032e-11,
#  'Rho': 1.209565162860536e-08}

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go


class OptionHedger:
    """
    Hedger/backtester for a EuropeanOption (single option or multi-leg strategy).
    Uses pricing/greeks from the provided 'option' instance (EuropeanOption).

    Conventions:
      - option._greeks returns Theta per DAY (as in your class)
      - Gamma PnL increment: 0.5 * Gamma_t * (dS)^2
      - Theta PnL increment: Theta_t * dt_days
      - Portfolio is self-financing with initial value 0 => portfolio value == cumulative PnL
    """
    def __init__(self, option):
        self.option = option

    # ----------------------------
    # Strategy-aware greeks
    # ----------------------------
    def _leg_greeks(self, S, K, T_left, opt_type, qty=1.0, sigma=None):
        if opt_type == "underlying":
            g = {"Price": S, "Delta": 1.0, "Gamma": 0.0, "Vega": 0.0, "Theta": 0.0, "Rho": 0.0}
        else:
            g = self.option._greeks(S, K, T_left, opt_type, sigma=sigma)
        return {k: qty * v for k, v in g.items()}

    def greeks(self, S, t_years, sigma=None):
        opt = self.option

        if not opt.derivatives:
            T_left = max(float(opt.T[0]) - t_years, 1e-12)
            return opt._greeks(S, float(opt.K[0]), T_left, opt.option_type, sigma=sigma)

        strat = opt.derivatives.lower()
        K = opt.K.astype(float)
        T = opt.T.astype(float)

        strategies = {
            "straddle": [("call", 0, +1), ("put", 0, +1)],
            "strangle": [("put", 0, +1), ("call", 1, +1)],
            "bull_call_spread": [("call", 0, +1), ("call", 1, -1)],
            "bear_put_spread":  [("put", 0, +1), ("put", 1, -1)],
            "butterfly": [("call", 0, +1), ("call", 1, -2), ("call", 2, +1)],
            "iron_condor": [("put", 0, +1), ("put", 1, -1), ("call", 2, +1), ("call", 3, -1)],
            "risk_reversal": [("put", 0, -1), ("call", 1, +1)],
            "synthetic_long": [("call", 0, +1), ("put", 0, -1)],
            "synthetic_short": [("call", 0, -1), ("put", 0, +1)],
            "call_ratio_spread": [("call", 0, +1), ("call", 1, -2)],
            "put_ratio_spread":  [("put", 0, +1), ("put", 1, -2)],
            "call_seagull": [("call", 0, +1), ("call", 1, -1), ("put", 2, -1)],

            # underlying explicitly
            "covered_call":   [("underlying", 0, +1), ("call", 0, -1)],
            "protective_put": [("underlying", 0, +1), ("put", 0, +1)],
            "collar":         [("underlying", 0, +1), ("put", 0, +1), ("call", 1, -1)],

            # calendars: T=[T_short, T_long], K[0]
            "call_calendar_spread": [("call_long", 0, +1), ("call_short", 0, -1)],
            "put_calendar_spread":  [("put_long", 0, +1), ("put_short", 0, -1)],
        }

        if strat not in strategies:
            raise ValueError(f"Unknown strategy '{strat}'.")

        agg = {"Price": 0.0, "Delta": 0.0, "Gamma": 0.0, "Vega": 0.0, "Theta": 0.0, "Rho": 0.0}

        for opt_type, k_idx, qty in strategies[strat]:
            if opt_type in ("call_long", "put_long", "call_short", "put_short"):
                if len(T) < 2:
                    raise ValueError("Calendar spread requires option.T = [T_short, T_long].")
                T_short, T_long = float(T[0]), float(T[1])
                T_left = max((T_long if opt_type.endswith("long") else T_short) - t_years, 1e-12)
                base_type = "call" if opt_type.startswith("call") else "put"
                leg = self._leg_greeks(S, float(K[k_idx]), T_left, base_type, qty=qty, sigma=sigma)
            else:
                T_left = max(float(T[0]) - t_years, 1e-12)
                leg = self._leg_greeks(S, float(K[k_idx]), T_left, opt_type, qty=qty, sigma=sigma)

            for k in agg:
                agg[k] += leg[k]

        return agg

    # ----------------------------
    # One-path delta hedging backtest
    # ----------------------------
    def run_delta_hedge(self, S_path, horizon_years, rebalance_every=1, sigma=None):
        S_path = np.asarray(S_path, dtype=float)
        n = len(S_path) - 1
        if n <= 0:
            raise ValueError("S_path must have length >= 2.")

        dt_year = horizon_years / n
        dt_days = dt_year * 365.0
        r = float(self.option.r)

        g0 = self.greeks(S_path[0], t_years=0.0, sigma=sigma)
        V0, Delta0 = g0["Price"], g0["Delta"]

        stock_pos = -Delta0
        cash = -V0 - stock_pos * S_path[0]  # initial portfolio value = 0

        pnl_cum = 0.0
        gamma_cum = 0.0
        theta_cum = 0.0
        resid_cum = 0.0

        rows = [{
            "step": 0,
            "t_years": 0.0,
            "S": S_path[0],
            "OptValue": V0,
            "Delta": g0["Delta"],
            "Gamma": g0["Gamma"],
            "Theta_per_day": g0["Theta"],
            "stock_pos": stock_pos,
            "cash": cash,
            "PnL_cum": 0.0,
            "GammaPnL_cum": 0.0,
            "ThetaPnL_cum": 0.0,
            "Residual_cum": 0.0,
        }]

        for i in range(n):
            t = i * dt_year
            S_t = S_path[i]
            S_next = S_path[i + 1]
            dS = S_next - S_t

            g_t = self.greeks(S_t, t_years=t, sigma=sigma)
            Gamma_t = g_t["Gamma"]
            Theta_t = g_t["Theta"]

            cash *= np.exp(r * dt_year)

            g_next = self.greeks(S_next, t_years=t + dt_year, sigma=sigma)
            V_next = g_next["Price"]

            port_before = V_next + stock_pos * S_next + cash

            if ((i + 1) % rebalance_every) == 0:
                Delta_new = g_next["Delta"]
                stock_new = -Delta_new
                trade = stock_new - stock_pos
                cash -= trade * S_next
                stock_pos = stock_new

            port_after = V_next + stock_pos * S_next + cash

            pnl_step = port_after - pnl_cum
            pnl_cum = port_after

            gamma_step = 0.5 * Gamma_t * (dS ** 2)
            theta_step = Theta_t * dt_days
            resid_step = pnl_step - (gamma_step + theta_step)

            gamma_cum += gamma_step
            theta_cum += theta_step
            resid_cum += resid_step

            rows.append({
                "step": i + 1,
                "t_years": (i + 1) * dt_year,
                "S": S_next,
                "OptValue": V_next,
                "Delta": g_next["Delta"],
                "Gamma": g_next["Gamma"],
                "Theta_per_day": g_next["Theta"],
                "stock_pos": stock_pos,
                "cash": cash,
                "PnL_cum": pnl_cum,
                "GammaPnL_cum": gamma_cum,
                "ThetaPnL_cum": theta_cum,
                "Residual_cum": resid_cum,
            })

        return pd.DataFrame(rows)

    # ----------------------------
    # (d) Hedging PnL uncertainty (Derman-style): Monte-Carlo std deviation
    # ----------------------------
    @staticmethod
    def simulate_gbm_paths(S0, mu, sigma_rw, horizon_years, n_steps, n_paths, seed=0):
        """
        Simulate GBM paths under 'real-world' parameters.
        Returns array shape (n_paths, n_steps+1)
        """
        rng = np.random.default_rng(seed)
        dt = horizon_years / n_steps
        Z = rng.standard_normal((n_paths, n_steps))
        increments = (mu - 0.5 * sigma_rw**2) * dt + sigma_rw * np.sqrt(dt) * Z
        logS = np.cumsum(increments, axis=1)
        logS = np.hstack([np.zeros((n_paths, 1)), logS])
        return S0 * np.exp(logS)

    def run_uncertainty_mc(
        self,
        S0,
        horizon_years,
        n_steps=63,
        n_paths=2000,
        mu=0.0,
        sigma_rw=0.20,
        rebalance_every=1,
        sigma_imp=None,
        seed=0,
        return_paths=False,
    ):
        """
        Estimates hedging PnL uncertainty via Monte-Carlo:
          std_t = Std[ PnL_cum(t) ] across paths

        - sigma_rw: spot diffusion vol used in simulation (realized)
        - sigma_imp: vol used for pricing/greeks during hedging (implied). If None => option.sigma
        Returns:
          summary_df (time grid with mean/std of PnL and Residual),
          pnl_terminal (array of terminal PnL),
          residual_terminal (array of terminal residual),
          optionally paths.
        """
        sigma_imp = self.option.sigma if sigma_imp is None else sigma_imp

        paths = self.simulate_gbm_paths(
            S0=S0, mu=mu, sigma_rw=sigma_rw,
            horizon_years=horizon_years, n_steps=n_steps, n_paths=n_paths, seed=seed
        )

        # store pnl and residual trajectories
        pnl_mat = np.empty((n_paths, n_steps + 1))
        res_mat = np.empty((n_paths, n_steps + 1))

        for j in range(n_paths):
            df = self.run_delta_hedge(
                S_path=paths[j],
                horizon_years=horizon_years,
                rebalance_every=rebalance_every,
                sigma=sigma_imp
            )
            pnl_mat[j, :] = df["PnL_cum"].to_numpy()
            res_mat[j, :] = df["Residual_cum"].to_numpy()

        t_grid = np.linspace(0.0, horizon_years, n_steps + 1)

        summary_df = pd.DataFrame({
            "t_years": t_grid,
            "PnL_mean": pnl_mat.mean(axis=0),
            "PnL_std": pnl_mat.std(axis=0, ddof=1),
            "Residual_mean": res_mat.mean(axis=0),
            "Residual_std": res_mat.std(axis=0, ddof=1),
        })

        pnl_terminal = pnl_mat[:, -1]
        res_terminal = res_mat[:, -1]

        if return_paths:
            return summary_df, pnl_terminal, res_terminal, paths

        return summary_df, pnl_terminal, res_terminal

    # ----------------------------
    # Plotting for uncertainty
    # ----------------------------
    @staticmethod
    def plot_uncertainty(summary_df, pnl_terminal, title="Hedging PnL uncertainty"):
        # Std over time
        fig1 = go.Figure()
        fig1.add_trace(go.Scatter(x=summary_df["t_years"], y=summary_df["PnL_std"], mode="lines", name="Std(PnL)"))
        fig1.add_trace(go.Scatter(x=summary_df["t_years"], y=summary_df["Residual_std"], mode="lines",
                                  name="Std(Residual)"))
        fig1.update_layout(
            title=f"{title} - standard deviation over time",
            xaxis_title="Time (years)",
            yaxis_title="Standard deviation",
            template="plotly_dark",
        )

        # Terminal histogram
        fig2 = go.Figure()
        fig2.add_trace(go.Histogram(x=pnl_terminal, nbinsx=60, name="Terminal PnL"))
        fig2.update_layout(
            title=f"{title} - terminal PnL distribution",
            xaxis_title="Terminal PnL",
            yaxis_title="Count",
            template="plotly_dark",
        )

        fig1.show()
        fig2.show()

    def compare_rebalance_frequencies(
        self,
        S0,
        horizon_years,
        freqs=(1, 5, 10),
        n_steps=63,
        n_paths=2000,
        mu=0.0,
        sigma_rw=0.20,
        sigma_imp=None,
        seed=0,
        title="Hedging uncertainty vs rebalancing frequency",
    ):
        """
        Convenience method: compares Std(PnL) across different hedge frequencies.
        """
        sigma_imp = self.option.sigma if sigma_imp is None else sigma_imp

        fig = go.Figure()
        for f in freqs:
            summary_df, pnl_terminal, _ = self.run_uncertainty_mc(
                S0=S0,
                horizon_years=horizon_years,
                n_steps=n_steps,
                n_paths=n_paths,
                mu=mu,
                sigma_rw=sigma_rw,
                rebalance_every=f,
                sigma_imp=sigma_imp,
                seed=seed,
            )
            fig.add_trace(go.Scatter(x=summary_df["t_years"], y=summary_df["PnL_std"], mode="lines",
                                     name=f"rebalance_every={f}"))
        fig.update_layout(
            title=title,
            xaxis_title="Time (years)",
            yaxis_title="Std(PnL)",
            template="plotly_dark",
        )
        fig.show()


# ----------------------------
# Example usage (plug-and-play)
# ----------------------------
if __name__ == "__main__":
    # EuropeanOption must already be defined (your class)

    horizon = 3/12
    S0 = 100.0

    # Example strategy
    opt = EuropeanOption(S=S0, K=[100, 105], T=[horizon], r=0.02, sigma=0.22, derivatives="bull_call_spread")
    hedger = OptionHedger(opt)


    # (c) Illustration of the evolution of the gamma / theta hedging PnL and the Gamma/Theta ratios

    df = hedger.run_delta_hedge(S, horizon_years=horizon, rebalance_every=1)

    OptionHedger.plot_results(df, title="Bull Call Spread - daily delta hedge")

    # (d) Uncertainty estimation
    summary_df, pnl_T, res_T = hedger.run_uncertainty_mc(
        S0=S0,
        horizon_years=horizon,
        n_steps=63,
        n_paths=10,
        mu=0.0,
        sigma_rw=0.20,   # realized/physical vol
        rebalance_every=1,
        sigma_imp=0.22,  # hedging/pricing vol (implied)
        seed=42
    )

    print("Terminal PnL mean:", float(pnl_T.mean()))
    print("Terminal PnL std :", float(pnl_T.std(ddof=1)))

    hedger.plot_uncertainty(summary_df, pnl_T, title="Derman-style hedging PnL uncertainty (MC std)")

    # Optional: show impact of hedge frequency on uncertainty
    hedger.compare_rebalance_frequencies(
        S0=S0,
        horizon_years=horizon,
        freqs=(1, 5, 10),
        n_steps=63,
        n_paths=10,
        mu=0.0,
        sigma_rw=0.20,
        sigma_imp=0.22,
        seed=7,
        title="Std(PnL) vs rebalancing frequency"
    )
# Out:
# Terminal PnL mean: -0.10097400009252452
# Terminal PnL std : 0.2056956316940239

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go


# ============================================================
# Child class: OptionHedgerWithCrash
# Extends your existing OptionHedger (must already be defined).
# Adds:
#  - crash spot path generator
#  - crash implied-vol path generator (vol spike + mean reversion)
#  - theta-hedging PnL analysis in crash scenario (e)
# ============================================================

class OptionHedgerWithCrash(OptionHedger):
    """
    Extends OptionHedger with crash-scenario tools.

    (e) Theta-hedging PnL in case of a market crash:
      - run delta hedge under a crash spot path
      - optionally use a time-varying implied vol path (sigma spike)
      - show cumulative Theta PnL vs total delta-hedged PnL and (Gamma+Theta)
    """

    # ----------------------------
    # Crash scenario builders
    # ----------------------------
    @staticmethod
    def make_crash_path(
        S0: float,
        horizon_years: float,
        n_steps: int = 63,
        crash_day: int = 5,
        crash_return: float = -0.20,
        pre_vol: float = 0.05,
        post_vol: float = 0.35,
        seed: int = 0,
    ):
        """
        Spot path with:
          - mild diffusion until crash_day
          - one-day jump crash_return (e.g. -20%)
          - higher-vol diffusion after crash
        Returns array of length n_steps+1.
        """
        if not (0 <= crash_day <= n_steps - 1):
            raise ValueError("crash_day must be in [0, n_steps-1].")

        rng = np.random.default_rng(seed)
        dt = horizon_years / n_steps

        S = np.empty(n_steps + 1)
        S[0] = S0

        # pre-crash diffusion
        for i in range(crash_day):
            z = rng.standard_normal()
            S[i + 1] = S[i] * np.exp((-0.5 * pre_vol**2) * dt + pre_vol * np.sqrt(dt) * z)

        # crash day jump
        S[crash_day + 1] = S[crash_day] * (1.0 + crash_return)

        # post-crash diffusion
        for i in range(crash_day + 1, n_steps):
            z = rng.standard_normal()
            S[i + 1] = S[i] * np.exp((-0.5 * post_vol**2) * dt + post_vol * np.sqrt(dt) * z)

        return S

    @staticmethod
    def make_crash_vol_path(
        sigma_base: float,
        horizon_years: float,
        n_steps: int,
        crash_day: int = 5,
        vol_jump: float = 0.18,
        mean_revert_to: float | None = None,
        kappa: float = 12.0,
    ):
        """
        Implied-vol path with:
          - sigma_base until crash
          - jump by +vol_jump at crash_day+1
          - exponential mean reversion afterwards
        Returns array length n_steps+1.
        """
        if mean_revert_to is None:
            mean_revert_to = sigma_base

        dt = horizon_years / n_steps
        sig = np.full(n_steps + 1, sigma_base, dtype=float)

        idx = crash_day + 1
        if idx <= n_steps:
            sig[idx] = sigma_base + vol_jump
            for i in range(idx + 1, n_steps + 1):
                tau = (i - idx) * dt
                sig[i] = mean_revert_to + (sig[idx] - mean_revert_to) * np.exp(-kappa * tau)

        return sig

    # ----------------------------
    # Delta hedge but using a sigma path (time-varying implied vol)
    # ----------------------------
    def run_delta_hedge_with_sigma_path(
        self,
        S_path,
        horizon_years,
        rebalance_every=1,
        sigma_path=None,
    ):
        """
        Same as OptionHedger.run_delta_hedge, but:
          - stores ThetaPnL_cum explicitly (needed for (e))
          - uses sigma_path[t] to compute greeks/price if provided

        Requires: parent OptionHedger has self.greeks(S, t_years, sigma=...).
        """
        S_path = np.asarray(S_path, dtype=float)
        n = len(S_path) - 1
        if n <= 0:
            raise ValueError("S_path must have length >= 2.")

        if sigma_path is not None:
            sigma_path = np.asarray(sigma_path, dtype=float)
            if len(sigma_path) != len(S_path):
                raise ValueError("sigma_path must have same length as S_path (n_steps+1).")

        dt_year = horizon_years / n
        dt_days = dt_year * 365.0
        r = float(self.option.r)

        sigma0 = sigma_path[0] if sigma_path is not None else None
        g0 = self.greeks(S_path[0], t_years=0.0, sigma=sigma0)
        V0, Delta0 = g0["Price"], g0["Delta"]

        stock_pos = -Delta0
        cash = -V0 - stock_pos * S_path[0]  # initial portfolio value = 0

        pnl_cum = 0.0
        gamma_cum = 0.0
        theta_cum = 0.0
        resid_cum = 0.0

        rows = [{
            "step": 0,
            "t_years": 0.0,
            "S": S_path[0],
            "OptValue": V0,
            "Delta": g0["Delta"],
            "Gamma": g0["Gamma"],
            "Theta_per_day": g0["Theta"],
            "stock_pos": stock_pos,
            "cash": cash,
            "PnL_cum": 0.0,
            "GammaPnL_cum": 0.0,
            "ThetaPnL_cum": 0.0,
            "Residual_cum": 0.0,
        }]

        for i in range(n):
            t = i * dt_year
            S_t = S_path[i]
            S_next = S_path[i + 1]
            dS = S_next - S_t

            sigma_t = sigma_path[i] if sigma_path is not None else None
            sigma_next = sigma_path[i + 1] if sigma_path is not None else None

            g_t = self.greeks(S_t, t_years=t, sigma=sigma_t)
            Gamma_t = g_t["Gamma"]
            Theta_t = g_t["Theta"]

            cash *= np.exp(r * dt_year)

            g_next = self.greeks(S_next, t_years=t + dt_year, sigma=sigma_next)
            V_next = g_next["Price"]

            port_before = V_next + stock_pos * S_next + cash

            if ((i + 1) % rebalance_every) == 0:
                Delta_new = g_next["Delta"]
                stock_new = -Delta_new
                trade = stock_new - stock_pos
                cash -= trade * S_next
                stock_pos = stock_new

            port_after = V_next + stock_pos * S_next + cash

            pnl_step = port_after - pnl_cum
            pnl_cum = port_after

            gamma_step = 0.5 * Gamma_t * (dS ** 2)
            theta_step = Theta_t * dt_days
            resid_step = pnl_step - (gamma_step + theta_step)

            gamma_cum += gamma_step
            theta_cum += theta_step
            resid_cum += resid_step

            rows.append({
                "step": i + 1,
                "t_years": (i + 1) * dt_year,
                "S": S_next,
                "OptValue": V_next,
                "Delta": g_next["Delta"],
                "Gamma": g_next["Gamma"],
                "Theta_per_day": g_next["Theta"],
                "stock_pos": stock_pos,
                "cash": cash,
                "PnL_cum": pnl_cum,
                "GammaPnL_cum": gamma_cum,
                "ThetaPnL_cum": theta_cum,
                "Residual_cum": resid_cum,
            })

        return pd.DataFrame(rows)

    # ----------------------------
    # (e) Theta hedging PnL during crash
    # ----------------------------
    def analyze_theta_hedging_in_crash(
        self,
        S0: float,
        horizon_years: float,
        n_steps: int = 63,
        crash_day: int = 5,
        crash_return: float = -0.20,
        pre_vol: float = 0.05,
        post_vol: float = 0.35,
        sigma_base: float | None = None,
        vol_jump: float = 0.18,
        kappa: float = 12.0,
        rebalance_every: int = 1,
        seed: int = 0,
        use_vol_spike: bool = True,
        show_plots: bool = True,
    ):
        """
        Produces a crash scenario and runs the hedge, then illustrates:
          - Cum Theta PnL (carry)
          - Cum Total delta-hedged PnL
          - Cum (Gamma+Theta)
        """
        if sigma_base is None:
            sigma_base = float(self.option.sigma)

        S_path = self.make_crash_path(
            S0=S0,
            horizon_years=horizon_years,
            n_steps=n_steps,
            crash_day=crash_day,
            crash_return=crash_return,
            pre_vol=pre_vol,
            post_vol=post_vol,
            seed=seed,
        )

        sigma_path = None
        if use_vol_spike:
            sigma_path = self.make_crash_vol_path(
                sigma_base=sigma_base,
                horizon_years=horizon_years,
                n_steps=n_steps,
                crash_day=crash_day,
                vol_jump=vol_jump,
                mean_revert_to=sigma_base,
                kappa=kappa,
            )

        df = self.run_delta_hedge_with_sigma_path(
            S_path=S_path,
            horizon_years=horizon_years,
            rebalance_every=rebalance_every,
            sigma_path=sigma_path,
        )

        crash_time_years = (crash_day + 1) * (horizon_years / n_steps)

        if show_plots:
            self._plot_crash_theta(df, crash_time_years, title="(e) Theta hedging PnL under crash")
            if sigma_path is not None:
                self._plot_crash_vol(sigma_path, horizon_years, title="Implied vol path (crash spike)")

        return df, S_path, sigma_path

    # ----------------------------
    # Plots
    # ----------------------------
    @staticmethod
    def _plot_crash_theta(df, crash_time_years, title):
        fig = go.Figure()
        fig.add_trace(go.Scatter(x=df["t_years"], y=df["PnL_cum"], mode="lines", name="Cum Total PnL (delta-hedged)"))
        fig.add_trace(go.Scatter(x=df["t_years"], y=df["ThetaPnL_cum"], mode="lines", name="Cum Theta PnL"))
        fig.add_trace(go.Scatter(
            x=df["t_years"],
            y=df["GammaPnL_cum"] + df["ThetaPnL_cum"],
            mode="lines",
            name="Cum (Gamma + Theta)"
        ))
        fig.add_vline(x=crash_time_years, line_width=2, line_dash="dash", line_color="white")
        fig.update_layout(
            title=title,
            xaxis_title="Time (years)",
            yaxis_title="PnL",
            template="plotly_dark",
        )
        fig.show()

    @staticmethod
    def _plot_crash_vol(sigma_path, horizon_years, title):
        n_steps = len(sigma_path) - 1
        t = np.linspace(0.0, horizon_years, n_steps + 1)
        fig = go.Figure()
        fig.add_trace(go.Scatter(x=t, y=sigma_path, mode="lines", name="sigma_imp(t)"))
        fig.update_layout(
            title=title,
            xaxis_title="Time (years)",
            yaxis_title="Implied volatility",
            template="plotly_dark",
        )
        fig.show()


# ============================================================
# Example usage
# ============================================================
if __name__ == "__main__":
    # Assumes:
    #  - EuropeanOption is defined (your pricer class)
    #  - OptionHedger is defined (your parent hedger class from earlier)
    #
    # Example option:
    horizon = 3/12
    S0 = 100.0

    opt = EuropeanOption(S=S0, K=[100], T=[horizon], r=0.02, sigma=0.22, option_type="call")

    # Parent class must work (i.e., implements greeks() as previously provided)
    hedger = OptionHedgerWithCrash(opt)

    df_crash, S_path, sigma_path = hedger.analyze_theta_hedging_in_crash(
        S0=S0,
        horizon_years=horizon,
        n_steps=63,
        crash_day=5,
        crash_return=-0.20,
        post_vol=0.40,
        vol_jump=0.20,
        rebalance_every=1,
        seed=123,
        use_vol_spike=True,
        show_plots=True
    )

    print("Terminal total PnL:", float(df_crash["PnL_cum"].iloc[-1]))
    print("Terminal theta PnL:", float(df_crash["ThetaPnL_cum"].iloc[-1]))
    print("Terminal (Gamma+Theta):", float((df_crash["GammaPnL_cum"].iloc[-1] + df_crash["ThetaPnL_cum"].iloc[-1])))
# Out:
# Terminal total PnL: 7.449790373335112
# Terminal theta PnL: -1.766116768778744
# Terminal (Gamma+Theta): 8.108558618540288

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go


class OptionHedgerWithRates(OptionHedger):
    """
    Extends OptionHedger to illustrate (f) Rho-hedging PnL for long maturities.

    Key idea:
      - When maturity is long, the option price has material sensitivity to rates (Rho).
      - If rates move and you only delta-hedge, you can get a systematic PnL drift
        from unhedged rho exposure.
      - You can illustrate "Rho hedging PnL" by:
          (i) running delta-only hedge under a rate path r(t)
          (ii) running delta+rho hedge using a cash/bond account as rho hedge
          (iii) decomposing the PnL and plotting the cumulative rho component.

    IMPORTANT about your EuropeanOption:
      - _greeks returns Rho per 1% (division by 100).
      - So: dV_due_to_rates ≈ Rho * (Δr in %) = Rho * (100 * Δr)
        if Δr is in absolute units (e.g., 0.01 = +100bp).
    """

    # ----------------------------
    # Rate path generator (simple)
    # ----------------------------
    @staticmethod
    def make_rate_path(
        r0: float,
        horizon_years: float,
        n_steps: int,
        model: str = "mean_revert",
        sigma_r: float = 0.01,
        kappa: float = 1.5,
        theta: float | None = None,
        shock_day: int | None = None,
        shock_size: float = 0.01,
        seed: int = 0,
    ):
        """
        Builds a simple rate path r(t):
          - model="rw": random walk
          - model="mean_revert": Ornstein-Uhlenbeck discretization
          - optional one-off shock

        Units: r in decimals (0.02 = 2%)
        sigma_r is annualized rate volatility in decimals.
        """
        rng = np.random.default_rng(seed)
        dt = horizon_years / n_steps
        r = np.empty(n_steps + 1)
        r[0] = r0

        if theta is None:
            theta = r0

        for i in range(n_steps):
            z = rng.standard_normal()
            if model == "rw":
                r[i + 1] = r[i] + sigma_r * np.sqrt(dt) * z
            elif model == "mean_revert":
                # OU: dr = kappa*(theta - r)dt + sigma_r dW
                r[i + 1] = r[i] + kappa * (theta - r[i]) * dt + sigma_r * np.sqrt(dt) * z
            else:
                raise ValueError("model must be one of: 'rw', 'mean_revert'.")

            if shock_day is not None and i + 1 == shock_day:
                r[i + 1] += shock_size

        return r

    # ----------------------------
    # Delta + Rho hedging backtest
    # ----------------------------
    def run_delta_rho_hedge(
        self,
        S_path,
        horizon_years,
        r_path,
        rebalance_every=1,
        sigma=None,
        hedge_rho=True,
        alpha = 1.0  # partial hedge constant
    ):
        """
        Self-financing hedged portfolio:
          - long option strategy
          - stock hedge for delta
          - rate hedge instrument for rho (if hedge_rho=True)

        Rho hedge instrument (simple proxy):
          - Use a cash/bond account B(t) with dB = r(t) B dt.
          - For small parallel shifts, holding q_B units of B gives sensitivity:
              d(q_B * B) ≈ q_B * B * dt * (Δr)   (not a perfect rho hedge)
          This is *not* a perfect DV01 hedge in practice (you'd use a zero-coupon bond or swap),
          but it's a clean classroom illustration: long maturities => rho matters.

        For a cleaner "DV01-like" hedge, we implement a pseudo ZCB:
          - price P(t) = exp(-r(t) * tau_bond)
          - dP/dr = -tau_bond * P  (rho of bond)
          - choose qty to offset option rho.

        We use tau_bond = remaining option maturity (natural long-term hedge proxy).

        Returns df with cumulative PnL and rho component.
        """
        S_path = np.asarray(S_path, dtype=float)
        r_path = np.asarray(r_path, dtype=float)

        n = len(S_path) - 1
        if len(r_path) != len(S_path):
            raise ValueError("r_path must have same length as S_path (n_steps+1).")
        if n <= 0:
            raise ValueError("S_path must have length >= 2.")

        dt_year = horizon_years / n
        dt_days = dt_year * 365.0

        # We'll temporarily overwrite option.r each step to price with r(t)
        r_original = float(self.option.r)

        # Initial greeks at t=0
        self.option.r = float(r_path[0])
        g0 = self.greeks(S_path[0], t_years=0.0, sigma=sigma)
        V0 = g0["Price"]
        Delta0 = g0["Delta"]
        Rho0 = g0["Rho"]  # per 1% rate move

        # Hedge positions
        stock_pos = -Delta0

        # Rho hedge instrument: pseudo ZCB with tau_bond = remaining option maturity
        tau0 = max(float(self.option.T[0]) - 0.0, 1e-12)
        P0 = np.exp(-r_path[0] * tau0)  # ZCB price
        bond_rho0 = -tau0 * P0          # dP/dr

        bond_pos = 0.0
        if hedge_rho:
            # Option rho in "per 1%" => convert to per 1 unit of r:
            # dV/dr ≈ Rho * 100  because Rho is per 1% = 0.01
            dV_dr0 = Rho0 * 100.0
            # Choose bond position to offset: bond_pos * bond_rho0 ≈ -dV/dr0
            bond_pos = -alpha* dV_dr0 / (bond_rho0 + 1e-12)
        
        # Cash so initial portfolio value is 0
        cash = -(V0 + stock_pos * S_path[0] + bond_pos * P0)

        pnl_cum = 0.0
        rho_cum = 0.0

        rows = [{
            "step": 0,
            "t_years": 0.0,
            "S": S_path[0],
            "r": r_path[0],
            "OptValue": V0,
            "Delta": Delta0,
            "Rho_per_1pct": Rho0,
            "stock_pos": stock_pos,
            "bond_pos": bond_pos,
            "bond_price": P0,
            "cash": cash,
            "PnL_cum": 0.0,
            "RhoPnL_cum": 0.0,
        }]

        for i in range(n):
            t = i * dt_year
            t_next = (i + 1) * dt_year

            S_t = S_path[i]
            S_next = S_path[i + 1]
            r_t = r_path[i]
            r_next = r_path[i + 1]

            # accrue cash at short rate r_t
            cash *= np.exp(r_t * dt_year)

            # option value at next step priced with r_next
            self.option.r = float(r_next)
            g_next = self.greeks(S_next, t_years=t_next, sigma=sigma)
            V_next = g_next["Price"]

            # bond price at next step with remaining maturity tau_next
            tau_next = max(float(self.option.T[0]) - t_next, 1e-12)
            P_next = np.exp(-r_next * tau_next)

            # Portfolio before re-hedge
            port_before = V_next + stock_pos * S_next + bond_pos * P_next + cash

            # Rho PnL increment (local approximation at time t)
            # Δr in ABS units; convert to % points because Rho is per 1%
            self.option.r = float(r_t)
            g_t = self.greeks(S_t, t_years=t, sigma=sigma)
            Rho_t = g_t["Rho"]
            dr = r_next - r_t
            rho_step = Rho_t * (100.0 * dr)  # since Rho per 1% and 1% = 0.01

            # Rebalance hedges periodically
            if ((i + 1) % rebalance_every) == 0:
                # delta hedge
                Delta_new = g_next["Delta"]
                stock_new = -Delta_new
                trade_stock = stock_new - stock_pos
                cash -= trade_stock * S_next
                stock_pos = stock_new

                # rho hedge
                if hedge_rho:
                    Rho_new = g_next["Rho"]
                    dV_dr = Rho_new * 100.0
                    bond_rho = -tau_next * P_next
                    bond_new = -alpha * dV_dr / (bond_rho + 1e-12)
                    trade_bond = bond_new - bond_pos
                    cash -= trade_bond * P_next
                    bond_pos = bond_new

            # Portfolio after re-hedge
            port_after = V_next + stock_pos * S_next + bond_pos * P_next + cash

            pnl_step = port_after - pnl_cum
            pnl_cum = port_after

            rho_cum += rho_step

            rows.append({
                "step": i + 1,
                "t_years": t_next,
                "S": S_next,
                "r": r_next,
                "OptValue": V_next,
                "Delta": g_next["Delta"],
                "Rho_per_1pct": g_next["Rho"],
                "stock_pos": stock_pos,
                "bond_pos": bond_pos,
                "bond_price": P_next,
                "cash": cash,
                "PnL_cum": pnl_cum,
                "RhoPnL_cum": rho_cum,
            })

        # restore original rate
        self.option.r = r_original

        return pd.DataFrame(rows)

    # ----------------------------
    # Plotting for (f)
    # ----------------------------
    @staticmethod
    def plot_rho_role(df_no_rho, df_with_rho, title="(f) Role of rho hedging for long maturities"):
        # PnL comparison
        fig1 = go.Figure()
        fig1.add_trace(go.Scatter(x=df_no_rho["t_years"], y=df_no_rho["PnL_cum"], mode="lines",
                                  name="Delta hedge only"))
        fig1.add_trace(go.Scatter(x=df_with_rho["t_years"], y=df_with_rho["PnL_cum"], mode="lines",
                                  name="Delta + Rho hedge"))
        fig1.update_layout(
            title=title + " - cumulative PnL",
            xaxis_title="Time (years)",
            yaxis_title="PnL",
            template="plotly_dark",
        )

        # Rate path + rho PnL proxy
        fig2 = go.Figure()
        fig2.add_trace(go.Scatter(x=df_no_rho["t_years"], y=df_no_rho["r"], mode="lines", name="r(t)"))
        fig2.update_layout(
            title=title + " - rate path",
            xaxis_title="Time (years)",
            yaxis_title="Rate (decimal)",
            template="plotly_dark",
        )

        fig3 = go.Figure()
        fig3.add_trace(go.Scatter(x=df_no_rho["t_years"], y=df_no_rho["RhoPnL_cum"], mode="lines",
                                  name="Cum RhoPnL (proxy) - delta only"))
        fig3.add_trace(go.Scatter(x=df_with_rho["t_years"], y=df_with_rho["RhoPnL_cum"], mode="lines",
                                  name="Cum RhoPnL (proxy) - delta+rho hedge"))
        fig3.update_layout(
            title=title + " - rho PnL contribution (proxy)",
            xaxis_title="Time (years)",
            yaxis_title="PnL",
            template="plotly_dark",
        )

        fig1.show()
        fig2.show()
        fig3.show()


# ============================================================
# Example usage: long maturity to make rho visible (e.g. 5Y)
# ============================================================
if __name__ == "__main__":
    # EuropeanOption and OptionHedger must already exist in your environment.

    S0 = 100.0
    T_long = 5.0         # 5 years to emphasize rho
    r0 = 0.02
    sigma_imp = 0.20

    n_steps = 252        # 1y daily steps; for 5y, you might use 5*252 in a real run
    horizon = 1.0        # illustrate on 1-year horizon with long maturity (still "long-dated")
                         # If you want full 5y hedge, set horizon=5.0 and n_steps=5*252.

    # Spot path (simple diffusion)
    rng = np.random.default_rng(1)
    dt = horizon / n_steps
    vol_rw = 0.18
    S = np.empty(n_steps + 1)
    S[0] = S0
    for i in range(n_steps):
        S[i + 1] = S[i] * np.exp((-0.5 * vol_rw**2) * dt + vol_rw * np.sqrt(dt) * rng.standard_normal())

    # Rate path with a shock + mean reversion
    r_path = OptionHedgerWithRates.make_rate_path(
        r0=r0,
        horizon_years=horizon,
        n_steps=n_steps,
        model="mean_revert",
        sigma_r=0.01,       # 1% rate vol
        kappa=1.2,
        theta=r0,
        shock_day=60,
        shock_size=0.01,    # +100bp shock
        seed=2
    )

    # Long-dated option (call)
    opt = EuropeanOption(S=S0, K=[100], T=[T_long], r=r0, sigma=sigma_imp, option_type="call")

    hedger = OptionHedgerWithRates(opt)

    # Delta hedge only
    df_delta = hedger.run_delta_rho_hedge(
        S_path=S,
        horizon_years=horizon,
        r_path=r_path,
        rebalance_every=1,
        sigma=sigma_imp,
        hedge_rho=False
    )

    # Delta + rho hedge
    df_delta_rho = hedger.run_delta_rho_hedge(
        S_path=S,
        horizon_years=horizon,
        r_path=r_path,
        rebalance_every=1,
        sigma=sigma_imp,
        hedge_rho=True, 
        alpha= 1.0
    )

    hedger.plot_rho_role(df_delta, df_delta_rho, title="(f) Rho hedging for long-dated options")

# %% [markdown]
# # **Part 2:** Dealing with key limitations of Black & Scholes modelling assumptions

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go


# ------------------------------------------------------------
# 1) Monte-Carlo spot paths (GBM)
# ------------------------------------------------------------
def simulate_gbm_paths(
    S0: float,
    horizon_years: float,
    n_steps: int,
    n_paths: int,
    mu: float = 0.0,
    sigma_rw: float = 0.20,
    seed: int = 0,
):
    """
    Returns paths of shape (n_paths, n_steps+1).
    GBM under "real-world" drift mu and realized vol sigma_rw.
    """
    rng = np.random.default_rng(seed)
    dt = horizon_years / n_steps
    Z = rng.standard_normal((n_paths, n_steps))
    incr = (mu - 0.5 * sigma_rw**2) * dt + sigma_rw * np.sqrt(dt) * Z
    logS = np.cumsum(incr, axis=1)
    logS = np.hstack([np.zeros((n_paths, 1)), logS])
    return S0 * np.exp(logS)


# ------------------------------------------------------------
# 2) Core analysis: impact of rebalance frequency
# ------------------------------------------------------------
def analyze_rebalancing_frequency(
    hedger,
    S0: float,
    horizon_years: float,
    freqs=(1, 5, 10, 21),
    n_steps: int = 63,
    n_paths: int = 3000,
    mu: float = 0.0,
    sigma_rw: float = 0.20,
    sigma_imp: float | None = None,
    seed: int = 0,
):
    """
    For each rebalance frequency f:
      - simulate paths
      - run delta hedge with rebalance_every=f
      - store PnL trajectories and terminal PnL distribution
      - compute std(PnL_t) across paths, and summary stats on terminal PnL

    Returns:
      results: dict[f] = {"summary": df_time, "pnl_T": array, "pnl_mat": array}
      stats_df: summary table by frequency
    """
    if sigma_imp is None:
        sigma_imp = float(hedger.option.sigma)

    paths = simulate_gbm_paths(
        S0=S0, horizon_years=horizon_years, n_steps=n_steps, n_paths=n_paths,
        mu=mu, sigma_rw=sigma_rw, seed=seed
    )

    t_grid = np.linspace(0.0, horizon_years, n_steps + 1)

    results = {}
    stats_rows = []

    for f in freqs:
        pnl_mat = np.empty((n_paths, n_steps + 1), dtype=float)

        for j in range(n_paths):
            df = hedger.run_delta_hedge(
                S_path=paths[j],
                horizon_years=horizon_years,
                rebalance_every=int(f),
                sigma=sigma_imp
            )
            pnl_mat[j, :] = df["PnL_cum"].to_numpy()

        pnl_T = pnl_mat[:, -1]

        df_time = pd.DataFrame({
            "t_years": t_grid,
            "PnL_mean": pnl_mat.mean(axis=0),
            "PnL_std": pnl_mat.std(axis=0, ddof=1),
        })

        # Terminal distribution stats (useful for the report)
        q05 = np.quantile(pnl_T, 0.05)
        q01 = np.quantile(pnl_T, 0.01)
        es05 = pnl_T[pnl_T <= q05].mean() if np.any(pnl_T <= q05) else np.nan

        stats_rows.append({
            "rebalance_every": int(f),
            "terminal_mean": float(pnl_T.mean()),
            "terminal_std": float(pnl_T.std(ddof=1)),
            "VaR_5%": float(q05),
            "VaR_1%": float(q01),
            "ES_5%": float(es05),
        })

        results[int(f)] = {
            "summary": df_time,
            "pnl_T": pnl_T,
            "pnl_mat": pnl_mat,
        }

    stats_df = pd.DataFrame(stats_rows).sort_values("rebalance_every").reset_index(drop=True)
    return results, stats_df


# ------------------------------------------------------------
# 3) Plots: std(PnL) over time and terminal PnL distributions
# ------------------------------------------------------------
def plot_std_over_time(results, title="(2a) Discrete delta hedging: std(PnL) vs rebalancing frequency"):
    fig = go.Figure()
    for f, obj in results.items():
        df_time = obj["summary"]
        fig.add_trace(go.Scatter(
            x=df_time["t_years"],
            y=df_time["PnL_std"],
            mode="lines",
            name=f"rebalance_every={f}"
        ))
    fig.update_layout(
        title=title,
        xaxis_title="Time (years)",
        yaxis_title="Std(PnL)",
        template="plotly_dark",
    )
    fig.show()


def plot_terminal_histograms(results, title="(2a) Terminal PnL distribution by rebalancing frequency", nbins=60):
    """
    Overlaid histograms. If it becomes unreadable, run it for fewer freqs or plot separately.
    """
    fig = go.Figure()
    for f, obj in results.items():
        fig.add_trace(go.Histogram(
            x=obj["pnl_T"],
            nbinsx=nbins,
            name=f"rebalance_every={f}",
            opacity=0.55
        ))
    fig.update_layout(
        title=title,
        xaxis_title="Terminal PnL",
        yaxis_title="Count",
        barmode="overlay",
        template="plotly_dark",
    )
    fig.show()


# ------------------------------------------------------------
# 4) Example usage
# ------------------------------------------------------------
if __name__ == "__main__":
    # You must have:
    #   - EuropeanOption defined
    #   - OptionHedger defined and instantiated as `hedger`
    #
    # Example: long-dated option accentuates greeks effects; for Derman 1996-style discreteness,
    # you can test both short (3M) and longer horizons.
    S0 = 100.0
    horizon = 3/12     # 3 months hedge horizon
    n_steps = 63       # ~daily
    n_paths = 100

    # Example option (single call)
    opt = EuropeanOption(S=S0, K=[100], T=[horizon], r=0.02, sigma=0.22, option_type="call")
    hedger = OptionHedger(opt)

    freqs = (1, 5, 10, 21)  # daily, weekly, bi-weekly, monthly(approx)
    results, stats_df = analyze_rebalancing_frequency(
        hedger=hedger,
        S0=S0,
        horizon_years=horizon,
        freqs=freqs,
        n_steps=n_steps,
        n_paths=n_paths,
        mu=0.0,
        sigma_rw=0.20,     # realized vol for spot simulation
        sigma_imp=0.22,    # vol used for pricing/hedging
        seed=42,
    )

    print(stats_df)

    plot_std_over_time(results)
    plot_terminal_histograms(results)
# Out:
#    rebalance_every  terminal_mean  terminal_std    VaR_5%    VaR_1%     ES_5%
# 0                1      -0.371140      0.425641 -1.130955 -1.527130 -1.396419
# 1                5      -0.355769      0.936511 -2.057578 -2.547900 -2.380633
# 2               10      -0.397412      1.233123 -2.418228 -3.258701 -2.979561
# 3               21      -0.338895      1.751901 -3.115060 -3.718780 -3.550540

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go


# ------------------------------------------------------------
# 1) Real-world scenarios: Trendy vs Rangy
# ------------------------------------------------------------
def simulate_trendy_gbm_paths(
    S0: float,
    horizon_years: float,
    n_steps: int,
    n_paths: int,
    mu: float = 0.08,
    sigma_rw: float = 0.20,
    seed: int = 0,
):
    """
    Trendy scenario: GBM with positive drift mu.
    Returns (n_paths, n_steps+1).
    """
    rng = np.random.default_rng(seed)
    dt = horizon_years / n_steps
    Z = rng.standard_normal((n_paths, n_steps))
    incr = (mu - 0.5 * sigma_rw**2) * dt + sigma_rw * np.sqrt(dt) * Z
    logS = np.cumsum(incr, axis=1)
    logS = np.hstack([np.zeros((n_paths, 1)), logS])
    return S0 * np.exp(logS)


def simulate_rangy_ou_log_paths(
    S0: float,
    horizon_years: float,
    n_steps: int,
    n_paths: int,
    kappa: float = 3.0,
    sigma_rw: float = 0.20,
    seed: int = 0,
):
    """
    Rangy scenario: mean-reverting log-price:
        dX = kappa*(m - X) dt + sigma_rw dW,   with X = log(S), m = log(S0)
    Then S = exp(X).
    This gives an intuitive "range-bound" behaviour around S0.

    sigma_rw is the diffusion scale on X (approx vol of log-price).
    Returns (n_paths, n_steps+1).
    """
    rng = np.random.default_rng(seed)
    dt = horizon_years / n_steps
    m = np.log(S0)

    X = np.empty((n_paths, n_steps + 1))
    X[:, 0] = m

    Z = rng.standard_normal((n_paths, n_steps))
    for i in range(n_steps):
        X[:, i + 1] = X[:, i] + kappa * (m - X[:, i]) * dt + sigma_rw * np.sqrt(dt) * Z[:, i]

    return np.exp(X)


# ------------------------------------------------------------
# 2) Run hedging under both scenarios + collect PnL distributions
# ------------------------------------------------------------
def compare_rangy_vs_trendy_pnl(
    hedger,
    S0: float,
    horizon_years: float,
    n_steps: int = 63,
    n_paths: int = 3000,
    rebalance_every: int = 1,
    sigma_imp: float | None = None,
    # trendy
    mu_trend: float = 0.08,
    sigma_trend: float = 0.20,
    # rangy
    kappa_rangy: float = 3.0,
    sigma_rangy: float = 0.20,
    seed: int = 0,
):
    """
    Returns:
      - stats_df: summary table
      - pnl_trendy, pnl_rangy: arrays of terminal PnL
    """
    if sigma_imp is None:
        sigma_imp = float(hedger.option.sigma)

    # simulate both sets of paths
    trendy_paths = simulate_trendy_gbm_paths(
        S0=S0, horizon_years=horizon_years, n_steps=n_steps, n_paths=n_paths,
        mu=mu_trend, sigma_rw=sigma_trend, seed=seed
    )

    rangy_paths = simulate_rangy_ou_log_paths(
        S0=S0, horizon_years=horizon_years, n_steps=n_steps, n_paths=n_paths,
        kappa=kappa_rangy, sigma_rw=sigma_rangy, seed=seed + 1
    )

    pnl_trendy = np.empty(n_paths)
    pnl_rangy = np.empty(n_paths)

    for j in range(n_paths):
        df_t = hedger.run_delta_hedge(trendy_paths[j], horizon_years, rebalance_every=rebalance_every, sigma=sigma_imp)
        pnl_trendy[j] = df_t["PnL_cum"].iloc[-1]

        df_r = hedger.run_delta_hedge(rangy_paths[j], horizon_years, rebalance_every=rebalance_every, sigma=sigma_imp)
        pnl_rangy[j] = df_r["PnL_cum"].iloc[-1]

    def stats(name, x):
        q05 = np.quantile(x, 0.05)
        q01 = np.quantile(x, 0.01)
        es05 = x[x <= q05].mean() if np.any(x <= q05) else np.nan
        return {
            "scenario": name,
            "mean": float(np.mean(x)),
            "std": float(np.std(x, ddof=1)),
            "VaR_5%": float(q05),
            "VaR_1%": float(q01),
            "ES_5%": float(es05),
        }

    stats_df = pd.DataFrame([
        stats("Trendy (GBM drift)", pnl_trendy),
        stats("Rangy (OU log MR)", pnl_rangy),
    ])

    return stats_df, pnl_trendy, pnl_rangy


# ------------------------------------------------------------
# 3) Plots
# ------------------------------------------------------------
def plot_pnl_distribution(pnl_trendy, pnl_rangy, title="(2b) PnL under trendy vs rangy real-world dynamics", nbins=60):
    fig = go.Figure()
    fig.add_trace(go.Histogram(x=pnl_trendy, nbinsx=nbins, name="Trendy", opacity=0.55))
    fig.add_trace(go.Histogram(x=pnl_rangy, nbinsx=nbins, name="Rangy", opacity=0.55))
    fig.update_layout(
        title=title + " – terminal PnL distribution",
        xaxis_title="Terminal PnL",
        yaxis_title="Count",
        barmode="overlay",
        template="plotly_dark",
    )
    fig.show()


def plot_box(pnl_trendy, pnl_rangy, title="(2b) Terminal PnL comparison (boxplot)"):
    fig = go.Figure()
    fig.add_trace(go.Box(y=pnl_trendy, name="Trendy"))
    fig.add_trace(go.Box(y=pnl_rangy, name="Rangy"))
    fig.update_layout(
        title=title,
        yaxis_title="Terminal PnL",
        template="plotly_dark",
    )
    fig.show()


# ------------------------------------------------------------
# 4) Example usage
# ------------------------------------------------------------
if __name__ == "__main__":
    # Requires EuropeanOption + OptionHedger already defined.
    S0 = 100.0
    horizon = 3/12
    n_steps = 63
    n_paths = 400

    # Example: long call (long gamma) typically benefits from rangy/high realized variance
    opt = EuropeanOption(S=S0, K=[100], T=[horizon], r=0.02, sigma=0.22, option_type="call")
    hedger = OptionHedger(opt)

    stats_df, pnl_trendy, pnl_rangy = compare_rangy_vs_trendy_pnl(
        hedger=hedger,
        S0=S0,
        horizon_years=horizon,
        n_steps=n_steps,
        n_paths=n_paths,
        rebalance_every=1,
        sigma_imp=0.22,      # hedging vol
        mu_trend=0.10,       # trending drift
        sigma_trend=0.20,
        kappa_rangy=4.0,     # stronger mean reversion => more range-bound
        sigma_rangy=0.20,
        seed=123,
    )

    print(stats_df)

    plot_pnl_distribution(pnl_trendy, pnl_rangy)
    plot_box(pnl_trendy, pnl_rangy)
# Out:
#              scenario      mean       std    VaR_5%    VaR_1%     ES_5%
# 0  Trendy (GBM drift) -0.412766  0.475298 -1.255989 -1.803309 -1.533148
# 1   Rangy (OU log MR) -0.458695  0.480533 -1.259774 -1.558761 -1.500735

# %%
from __future__ import annotations
from dataclasses import dataclass
from abc import ABC, abstractmethod
import numpy as np
import pandas as pd


# ============================================================
# 1) Fees & execution
# ============================================================

class FeeModel(ABC):
    @abstractmethod
    def fee(self, notional: float) -> float: ...


class FixedBpsFee(FeeModel):
    def __init__(self, bps: float):
        self.bps = float(bps)

    def fee(self, notional: float) -> float:
        return abs(notional) * self.bps / 10_000.0


class MinFloorFee(FeeModel):
    def __init__(self, bps: float, minimum: float):
        self.bps = float(bps)
        self.minimum = float(minimum)

    def fee(self, notional: float) -> float:
        return max(abs(notional) * self.bps / 10_000.0, self.minimum)


class Broker:
    def __init__(self, fee_model: FeeModel):
        self.fee_model = fee_model

    def commission(self, notional: float) -> float:
        return self.fee_model.fee(notional)


@dataclass(frozen=True)
class ExecutionModel:
    """
    Simple bid/ask model:
      executed_price = mid +/- half_spread
    half_spread is in price units (not bps).
    """
    half_spread: float

    def execute_price(self, mid: float, qty: float) -> float:
        # qty > 0 = buy => pay ask = mid + hs ; qty < 0 sell => receive bid = mid - hs
        return mid + self.half_spread if qty > 0 else mid - self.half_spread


# ============================================================
# 2) Trade bookkeeping
# ============================================================

@dataclass
class Trade:
    instrument: str     # "UNDERLYING" or "OPT_HEDGE"
    qty: float          # signed
    price: float        # executed
    notional: float     # qty * price
    fee: float          # commission


# ============================================================
# 3) Hedging engine: Delta-only vs Delta+Gamma
# ============================================================

class HedgingEngine:
    """
    Self-financing hedge backtester with transaction costs.

    Instruments:
      - Underlying (continuous qty, priced at S)
      - Optional gamma-hedge option (one chosen EuropeanOption, traded in qty q_g)

    Assumes you already have:
      - target option: self.opt_target (EuropeanOption)
      - hedge option:  self.opt_hedge  (EuropeanOption) for gamma hedge
    """

    def __init__(
        self,
        opt_target,                 # EuropeanOption
        broker_underlying: Broker,
        exec_underlying: ExecutionModel,
        broker_option: Broker,
        exec_option: ExecutionModel,
        opt_hedge=None,             # EuropeanOption or None
    ):
        self.opt_target = opt_target
        self.opt_hedge = opt_hedge
        self.broker_u = broker_underlying
        self.exec_u = exec_underlying
        self.broker_o = broker_option
        self.exec_o = exec_option

    def _target_greeks(self, S: float, T_left: float, sigma=None):
        return self.opt_target._greeks(S, float(self.opt_target.K[0]), T_left, self.opt_target.option_type, sigma=sigma)

    def _hedge_greeks(self, S: float, T_left: float, sigma=None):
        if self.opt_hedge is None:
            raise ValueError("opt_hedge is None: cannot gamma-hedge.")
        # hedge option is assumed single-leg
        return self.opt_hedge._greeks(S, float(self.opt_hedge.K[0]), T_left, self.opt_hedge.option_type, sigma=sigma)

    def run(
        self,
        S_path,
        horizon_years: float,
        rebalance_every: int = 1,
        sigma_imp=None,
        mode: str = "DELTA_ONLY",   # "DELTA_ONLY" or "DELTA_GAMMA"
    ) -> pd.DataFrame:
        """
        Returns a DataFrame with:
          - PnL_no_costs: self-financing PnL ignoring spread/fees (mid execution)
          - PnL_net: PnL including spread + fees
          - costs_cum
          - positions (underlying qty, hedge option qty)
        """
        S_path = np.asarray(S_path, float)
        n = len(S_path) - 1
        if n <= 0:
            raise ValueError("S_path must have length >= 2.")
        if mode not in ("DELTA_ONLY", "DELTA_GAMMA"):
            raise ValueError("mode must be DELTA_ONLY or DELTA_GAMMA")

        dt = horizon_years / n
        dt_days = 365.0 * dt
        r = float(self.opt_target.r)
        sigma_imp = float(self.opt_target.sigma if sigma_imp is None else sigma_imp)

        # Bookkeeping
        cash_no_cost = 0.0
        cash_net = 0.0
        pos_u = 0.0           # underlying position
        pos_g = 0.0           # gamma hedge option position
        costs_cum = 0.0
        trades: list[Trade] = []

        # Initial setup: value target option at t=0 (mid)
        T0 = float(self.opt_target.T[0])
        g0 = self._target_greeks(S_path[0], T_left=T0, sigma=sigma_imp)
        V0 = g0["Price"]

        # Start portfolio value 0: long option funded by cash (both accounting versions)
        cash_no_cost -= V0
        cash_net -= V0

        # Initial hedge at t=0 (if rebalance day)
        def rebalance(t_years, S_mid):
            nonlocal pos_u, pos_g, cash_no_cost, cash_net, costs_cum, trades

            T_left = max(T0 - t_years, 1e-12)

            g_t = self._target_greeks(S_mid, T_left, sigma=sigma_imp)
            Delta_t = g_t["Delta"]
            Gamma_t = g_t["Gamma"]

            # --- Gamma hedge: choose q_g so that Gamma_total = 0 ---
            qg_new = pos_g
            if mode == "DELTA_GAMMA":
                gh = self._hedge_greeks(S_mid, T_left, sigma=sigma_imp)
                Gamma_h = gh["Gamma"]
                # seuil plus réaliste + comportement stable
                EPS_GAMMA = 1e-8
                
                # Si gamma hedge devient trop petit (ou très proche de maturité),
                # on ne recalcule pas qg : on freeze la position existante.
                if abs(Gamma_h) < EPS_GAMMA or T_left < 2/365:
                    qg_new = pos_g
                else:
                    qg_new = -Gamma_t / Gamma_h

                dqg = qg_new - pos_g
                if abs(dqg) > 0:
                    # mid price for no_costs
                    price_mid = gh["Price"]
                    cash_no_cost -= dqg * price_mid

                    # executed with spread + commission for net
                    price_exec = self.exec_o.execute_price(price_mid, dqg)
                    notional = dqg * price_exec
                    fee = self.broker_o.commission(notional)
                    cash_net -= notional + fee
                    costs_cum += (abs(dqg) * abs(price_exec - price_mid) + fee)

                    trades.append(Trade("OPT_HEDGE", dqg, price_exec, notional, fee))
                    pos_g = qg_new

            # --- Delta hedge on total portfolio (target + qg*hedge) ---
            total_delta = Delta_t
            if mode == "DELTA_GAMMA":
                gh_now = self._hedge_greeks(S_mid, T_left, sigma=sigma_imp)
                total_delta += pos_g * gh_now["Delta"]

            # Choose underlying position to make total delta = 0:
            pu_new = -total_delta
            dpu = pu_new - pos_u

            if abs(dpu) > 0:
                # no_costs: trade at mid
                cash_no_cost -= dpu * S_mid

                # net: trade with spread + commission
                S_exec = self.exec_u.execute_price(S_mid, dpu)
                notional = dpu * S_exec
                fee = self.broker_u.commission(notional)
                cash_net -= notional + fee
                costs_cum += (abs(dpu) * abs(S_exec - S_mid) + fee)

                trades.append(Trade("UNDERLYING", dpu, S_exec, notional, fee))
                pos_u = pu_new

        # Initial rebalance at t=0
        rebalance(0.0, S_path[0])

        rows = []
        rows.append({
            "step": 0, "t_years": 0.0, "S": S_path[0],
            "pos_underlying": pos_u, "pos_gamma_opt": pos_g,
            "cash_no_cost": cash_no_cost, "cash_net": cash_net,
            "costs_cum": costs_cum, "PnL_no_costs": 0.0, "PnL_net": 0.0,
        })

        pnl0_no = 0.0
        pnl0_net = 0.0

        for i in range(n):
            t = i * dt
            t_next = (i + 1) * dt
            S_next = S_path[i + 1]

            # accrue cash at r
            cash_no_cost *= np.exp(r * dt)
            cash_net *= np.exp(r * dt)

            # rebalance at next step if scheduled (using next mid)
            if ((i + 1) % rebalance_every) == 0:
                rebalance(t_next, S_next)

            # mark-to-market portfolio value (mid)
            T_left_next = max(T0 - t_next, 1e-12)
            g_target_next = self._target_greeks(S_next, T_left_next, sigma=sigma_imp)
            V_target_next = g_target_next["Price"]

            V_hedge_next = 0.0
            if mode == "DELTA_GAMMA":
                g_hedge_next = self._hedge_greeks(S_next, T_left_next, sigma=sigma_imp)
                V_hedge_next = pos_g * g_hedge_next["Price"]

            port_no = V_target_next + pos_u * S_next + V_hedge_next + cash_no_cost
            port_net = V_target_next + pos_u * S_next + V_hedge_next + cash_net

            # By construction portfolio started at 0
            pnl_no = port_no
            pnl_net = port_net

            rows.append({
                "step": i + 1,
                "t_years": t_next,
                "S": S_next,
                "pos_underlying": pos_u,
                "pos_gamma_opt": pos_g,
                "cash_no_cost": cash_no_cost,
                "cash_net": cash_net,
                "costs_cum": costs_cum,
                "PnL_no_costs": pnl_no,
                "PnL_net": pnl_net,
            })

        df = pd.DataFrame(rows)
        return df


# ============================================================
# Example usage
# ============================================================
if __name__ == "__main__":
    # Requires your EuropeanOption class
    S0 = 100.0
    T = 3/12
    n_steps = 63
    horizon = T

    # Simulate a toy path
    rng = np.random.default_rng(0)
    dt = horizon / n_steps
    vol_rw = 0.20
    S = np.empty(n_steps + 1)
    S[0] = S0
    for i in range(n_steps):
        S[i + 1] = S[i] * np.exp((-0.5 * vol_rw**2) * dt + vol_rw * np.sqrt(dt) * rng.standard_normal())

    # Target option to hedge
    opt_target = EuropeanOption(S=S0, K=[100], T=[T], r=0.02, sigma=0.22, option_type="call")

    # Hedge gamma with another option (e.g. ATM put/call with same T; you can pick different strike)
    opt_hedge = EuropeanOption(S=S0, K=[100], T=[T], r=0.02, sigma=0.22, option_type="call")

    # Costs
    broker_u = Broker(FixedBpsFee(1.0))      # 1 bp on underlying notional
    broker_o = Broker(MinFloorFee(5.0, 0.5)) # 5 bps with 0.5 min on option notional

    exec_u = ExecutionModel(half_spread=0.005)  # 1 cent full spread
    exec_o = ExecutionModel(half_spread=0.02)   # 4 cents full spread

    engine = HedgingEngine(
        opt_target=opt_target,
        opt_hedge=opt_hedge,
        broker_underlying=broker_u,
        exec_underlying=exec_u,
        broker_option=broker_o,
        exec_option=exec_o
    )

    df_delta = engine.run(S, horizon, rebalance_every=1, mode="DELTA_ONLY")
    df_dg    = engine.run(S, horizon, rebalance_every=1, mode="DELTA_GAMMA")

    print("Delta-only terminal net PnL:", float(df_delta["PnL_net"].iloc[-1]))
    print("Delta+Gamma terminal net PnL:", float(df_dg["PnL_net"].iloc[-1]))
    print("Delta-only costs:", float(df_delta["costs_cum"].iloc[-1]))
    print("Delta+Gamma costs:", float(df_dg["costs_cum"].iloc[-1]))
# Out:
# Delta-only terminal net PnL: -0.641789553393437
# Delta+Gamma terminal net PnL: -0.5226065108468861
# Delta-only costs: 0.042805420281296344
# Delta+Gamma costs: 0.5199999999999996

# %%
from __future__ import annotations
from dataclasses import dataclass
from abc import ABC, abstractmethod
import numpy as np
import pandas as pd


# ============================================================
# Fees & execution (identique à ton esprit)
# ============================================================

class FeeModel(ABC):
    @abstractmethod
    def fee(self, notional: float) -> float: ...


class FixedBpsFee(FeeModel):
    def __init__(self, bps: float):
        self.bps = float(bps)

    def fee(self, notional: float) -> float:
        return abs(notional) * self.bps / 10_000.0


class MinFloorFee(FeeModel):
    def __init__(self, bps: float, minimum: float):
        self.bps = float(bps)
        self.minimum = float(minimum)

    def fee(self, notional: float) -> float:
        return max(abs(notional) * self.bps / 10_000.0, self.minimum)


class Broker:
    def __init__(self, fee_model: FeeModel):
        self.fee_model = fee_model

    def commission(self, notional: float) -> float:
        return self.fee_model.fee(notional)


@dataclass(frozen=True)
class ExecutionModel:
    half_spread: float  # price units

    def execute_price(self, mid: float, qty: float) -> float:
        return mid + self.half_spread if qty > 0 else mid - self.half_spread


# ============================================================
# Helpers: deterministic sigma and simulation
# ============================================================

def build_sigma_path(
    horizon_years: float,
    n_steps: int,
    sigma0: float = 0.22,
    sigma1: float = 0.30,
    t_peak_years: float = 0.10,
):
    """
    Simple deterministic term: sigma goes from sigma0 -> sigma1 (until t_peak),
    then back to sigma0 by maturity. Returns array length n_steps+1.
    """
    t = np.linspace(0.0, horizon_years, n_steps + 1)
    sig = np.empty_like(t)
    for i, ti in enumerate(t):
        if ti <= t_peak_years:
            w = ti / max(t_peak_years, 1e-12)
            sig[i] = (1 - w) * sigma0 + w * sigma1
        else:
            w = (ti - t_peak_years) / max(horizon_years - t_peak_years, 1e-12)
            sig[i] = (1 - w) * sigma1 + w * sigma0
    return sig


def simulate_gbm_with_deterministic_sigma(
    S0: float,
    horizon_years: float,
    n_steps: int,
    sigma_path: np.ndarray,
    mu: float = 0.0,
    seed: int = 0,
):
    """
    Real-world dynamics with time-varying deterministic vol:
      dS/S = mu dt + sigma(t) dW
    """
    rng = np.random.default_rng(seed)
    dt = horizon_years / n_steps
    S = np.empty(n_steps + 1, dtype=float)
    S[0] = S0
    for i in range(n_steps):
        sig = float(sigma_path[i])
        z = rng.standard_normal()
        S[i + 1] = S[i] * np.exp((mu - 0.5 * sig**2) * dt + sig * np.sqrt(dt) * z)
    return S


# ============================================================
# Core class: HedgingEngineRatios
# - Delta hedging ratio fixed to 100% in your questions (but parameterized)
# - Gamma hedging ratio can be < 100% (part d)
# - Optional 2nd hedge option to also hedge Vega (part e)
# ============================================================

class HedgingEngineRatios:
    def __init__(
        self,
        opt_target,                     # EuropeanOption (single leg or your strategy wrapper if you use it)
        broker_underlying: Broker,
        exec_underlying: ExecutionModel,
        broker_option: Broker,
        exec_option: ExecutionModel,
        opt_gamma_hedge=None,           # EuropeanOption
        opt_vega_hedge=None,            # EuropeanOption (2nd hedge option for DGV)
    ):
        self.opt_target = opt_target
        self.opt_gamma_hedge = opt_gamma_hedge
        self.opt_vega_hedge = opt_vega_hedge
        self.broker_u = broker_underlying
        self.exec_u = exec_underlying
        self.broker_o = broker_option
        self.exec_o = exec_option

    def _greeks_single(self, opt, S: float, T_left: float, sigma: float):
        # Works with your EuropeanOption (single option)
        return opt._greeks(S, float(opt.K[0]), T_left, opt.option_type, sigma=sigma)

    def run(
        self,
        S_path,
        horizon_years: float,
        rebalance_every: int = 1,
        sigma_path: np.ndarray | None = None,   # if None => constant opt_target.sigma
        delta_ratio: float = 1.0,
        gamma_ratio: float = 0.0,               # part (d): 0.8
        vega_ratio: float = 0.0,                # part (e): 1.0
        cap_option_position: float | None = None,
        freeze_near_expiry_days: float = 2.0,
    ) -> pd.DataFrame:
        """
        Self-financing with costs.
        Portfolio instruments:
          - long target option
          - underlying (delta hedge)
          - optional gamma hedge option (qty q1)
          - optional vega hedge option  (qty q2) to solve (Gamma,Vega)

        Ratios:
          - delta_ratio = 1.0 => fully delta hedged (delta total = 0)
          - gamma_ratio = 0.8 => hedge 80% of target gamma (leave 20% residual)
          - vega_ratio  = 1.0 => hedge 100% of target vega (leave 0 residual)
        """
        S_path = np.asarray(S_path, float)
        n = len(S_path) - 1
        if n <= 0:
            raise ValueError("S_path must have length >= 2.")

        dt = horizon_years / n
        r = float(self.opt_target.r)
        T0 = float(self.opt_target.T[0])
        freeze_years = float(freeze_near_expiry_days) / 365.0

        if sigma_path is None:
            sigma_path = np.full(n + 1, float(self.opt_target.sigma), dtype=float)
        else:
            sigma_path = np.asarray(sigma_path, float)
            if len(sigma_path) != len(S_path):
                raise ValueError("sigma_path must have same length as S_path (n_steps+1).")

        # positions
        pos_u = 0.0
        pos_g1 = 0.0
        pos_g2 = 0.0

        # cash accounts (no_cost vs net) to show impact
        cash_no = 0.0
        cash_net = 0.0
        costs_cum = 0.0

        # initial: long target option financed by cash
        g0 = self._greeks_single(self.opt_target, S_path[0], T_left=T0, sigma=float(sigma_path[0]))
        V0 = g0["Price"]
        cash_no -= V0
        cash_net -= V0

        def trade_option(qty, mid_price, label):
            nonlocal cash_no, cash_net, costs_cum
            if abs(qty) < 1e-14:
                return
            # no_cost: mid
            cash_no -= qty * mid_price

            # net: spread + fees
            px_exec = self.exec_o.execute_price(mid_price, qty)
            notional = qty * px_exec
            fee = self.broker_o.commission(notional)
            cash_net -= notional + fee

            costs_cum += abs(qty) * abs(px_exec - mid_price) + fee

        def trade_underlying(qty, mid_price):
            nonlocal cash_no, cash_net, costs_cum
            if abs(qty) < 1e-14:
                return
            cash_no -= qty * mid_price

            px_exec = self.exec_u.execute_price(mid_price, qty)
            notional = qty * px_exec
            fee = self.broker_u.commission(notional)
            cash_net -= notional + fee

            costs_cum += abs(qty) * abs(px_exec - mid_price) + fee

        def rebalance(t_years, S_mid, sig):
            nonlocal pos_u, pos_g1, pos_g2
            T_left = max(T0 - t_years, 1e-12)

            # freeze hedges very close to expiry (stability + realism)
            if T_left <= freeze_years:
                return

            gt = self._greeks_single(self.opt_target, S_mid, T_left, sig)
            Delta_t, Gamma_t, Vega_t = gt["Delta"], gt["Gamma"], gt["Vega"]

            # --- Solve gamma / vega hedges ---
            # targets for hedge: offset a fraction of target exposures
            gamma_rhs = -gamma_ratio * Gamma_t
            vega_rhs  = -vega_ratio  * Vega_t

            # CASE 1: Only gamma hedge (one option)
            if (gamma_ratio > 0.0) and (self.opt_gamma_hedge is not None) and (vega_ratio == 0.0 or self.opt_vega_hedge is None):
                gh1 = self._greeks_single(self.opt_gamma_hedge, S_mid, T_left, sig)
                G1 = gh1["Gamma"]

                EPS = 1e-8
                if abs(G1) > EPS:
                    q1_new = gamma_rhs / G1
                    if cap_option_position is not None:
                        q1_new = float(np.clip(q1_new, -cap_option_position, cap_option_position))

                    dq1 = q1_new - pos_g1
                    trade_option(dq1, gh1["Price"], "OPT_GAMMA")
                    pos_g1 = q1_new

            # CASE 2: Full (Gamma,Vega) hedge (two options)
            if (self.opt_gamma_hedge is not None) and (self.opt_vega_hedge is not None) and (gamma_ratio > 0.0 or vega_ratio > 0.0):
                gh1 = self._greeks_single(self.opt_gamma_hedge, S_mid, T_left, sig)
                gh2 = self._greeks_single(self.opt_vega_hedge, S_mid, T_left, sig)

                G1, V1 = gh1["Gamma"], gh1["Vega"]
                G2, V2 = gh2["Gamma"], gh2["Vega"]

                A = np.array([[G1, G2], [V1, V2]], dtype=float)
                b = np.array([gamma_rhs, vega_rhs], dtype=float)

                # robust solve
                det = np.linalg.det(A)
                if abs(det) > 1e-10:
                    q_new = np.linalg.solve(A, b)
                    q1_new, q2_new = float(q_new[0]), float(q_new[1])
                    if cap_option_position is not None:
                        q1_new = float(np.clip(q1_new, -cap_option_position, cap_option_position))
                        q2_new = float(np.clip(q2_new, -cap_option_position, cap_option_position))

                    dq1 = q1_new - pos_g1
                    dq2 = q2_new - pos_g2
                    trade_option(dq1, gh1["Price"], "OPT_1")
                    trade_option(dq2, gh2["Price"], "OPT_2")
                    pos_g1, pos_g2 = q1_new, q2_new
                # else: ill-conditioned -> do nothing (freeze), keeps run stable

            # --- Delta hedge on total portfolio ---
            total_delta = Delta_t
            if self.opt_gamma_hedge is not None:
                gh1_now = self._greeks_single(self.opt_gamma_hedge, S_mid, T_left, sig)
                total_delta += pos_g1 * gh1_now["Delta"]
            if self.opt_vega_hedge is not None:
                gh2_now = self._greeks_single(self.opt_vega_hedge, S_mid, T_left, sig)
                total_delta += pos_g2 * gh2_now["Delta"]

            # delta_ratio=1 => set total delta to zero
            # residual delta = (1-delta_ratio)*total_delta, so desired underlying position:
            pos_u_new = -delta_ratio * total_delta
            dpu = pos_u_new - pos_u
            trade_underlying(dpu, S_mid)
            pos_u = pos_u_new

        # initial rebalance
        rebalance(0.0, S_path[0], float(sigma_path[0]))

        rows = []
        rows.append({
            "step": 0, "t_years": 0.0, "S": S_path[0], "sigma": float(sigma_path[0]),
            "pos_underlying": pos_u, "pos_opt1": pos_g1, "pos_opt2": pos_g2,
            "cash_no_cost": cash_no, "cash_net": cash_net, "costs_cum": costs_cum,
            "PnL_no_costs": 0.0, "PnL_net": 0.0,
        })

        for i in range(n):
            t_next = (i + 1) * dt
            S_next = S_path[i + 1]
            sig_next = float(sigma_path[i + 1])

            # cash accrual
            cash_no *= np.exp(r * dt)
            cash_net *= np.exp(r * dt)

            # rebalance
            if ((i + 1) % rebalance_every) == 0:
                rebalance(t_next, S_next, sig_next)

            # MTM (mid) at next step
            T_left_next = max(T0 - t_next, 1e-12)

            gT = self._greeks_single(self.opt_target, S_next, T_left_next, sig_next)
            Vt = gT["Price"]

            Vh = 0.0
            if self.opt_gamma_hedge is not None:
                g1 = self._greeks_single(self.opt_gamma_hedge, S_next, T_left_next, sig_next)
                Vh += pos_g1 * g1["Price"]
            if self.opt_vega_hedge is not None:
                g2 = self._greeks_single(self.opt_vega_hedge, S_next, T_left_next, sig_next)
                Vh += pos_g2 * g2["Price"]

            port_no = Vt + pos_u * S_next + Vh + cash_no
            port_net = Vt + pos_u * S_next + Vh + cash_net

            rows.append({
                "step": i + 1, "t_years": t_next, "S": S_next, "sigma": sig_next,
                "pos_underlying": pos_u, "pos_opt1": pos_g1, "pos_opt2": pos_g2,
                "cash_no_cost": cash_no, "cash_net": cash_net, "costs_cum": costs_cum,
                "PnL_no_costs": port_no, "PnL_net": port_net,
            })

        return pd.DataFrame(rows)

K0 = 100
# Target option
opt_target = EuropeanOption(S=S0, K=[K0], T=[T], r=0.02, sigma=0.22, option_type="call")

# Gamma hedge option (une seule suffit pour (d))
opt_gamma = EuropeanOption(S=S0, K=[K0], T=[T], r=0.02, sigma=0.22, option_type="call")

engine = HedgingEngineRatios(
    opt_target=opt_target,
    opt_gamma_hedge=opt_gamma,
    opt_vega_hedge=None,
    broker_underlying=Broker(FixedBpsFee(1.0)),
    exec_underlying=ExecutionModel(half_spread=0.005),
    broker_option=Broker(FixedBpsFee(5.0)),
    exec_option=ExecutionModel(half_spread=0.02),
)

df_full_DG = engine.run(S_path, horizon_years=T, rebalance_every=1, delta_ratio=1.0, gamma_ratio=1.0, vega_ratio=0.0)
df_part_DG = engine.run(S_path, horizon_years=T, rebalance_every=1, delta_ratio=1.0, gamma_ratio=0.8, vega_ratio=0.0)

print("Full DG net terminal:", float(df_full_DG["PnL_net"].iloc[-1]))
print("Partial DG (80% gamma) net terminal:", float(df_part_DG["PnL_net"].iloc[-1]))
print("Costs full DG:", float(df_full_DG["costs_cum"].iloc[-1]))
print("Costs partial DG:", float(df_part_DG["costs_cum"].iloc[-1]))
# Out:
# Full DG net terminal: -0.0224163551129685
# Partial DG (80% gamma) net terminal: 1.487435931429372
# Costs full DG: 0.022304553075418232
# Costs partial DG: 0.025372548489755002

# %%
S0 = 100.0
T = 3/12
n_steps = 63

sigma_path = build_sigma_path(T, n_steps, sigma0=0.22, sigma1=0.32, t_peak_years=0.08)
S_path = simulate_gbm_with_deterministic_sigma(S0, T, n_steps, sigma_path, mu=0.0, seed=1)

opt_target = EuropeanOption(S=S0, K=[100], T=[T], r=0.02, sigma=0.22, option_type="call")

# Deux options de hedge (même T, strikes différents -> matrice (Gamma,Vega) non singulière)
opt1 = EuropeanOption(S=S0, K=[100], T=[T], r=0.02, sigma=0.22, option_type="call")  # ATM
opt2 = EuropeanOption(S=S0, K=[110], T=[T], r=0.02, sigma=0.22, option_type="call")  # OTM (diff greeks)

engine = HedgingEngineRatios(
    opt_target=opt_target,
    opt_gamma_hedge=opt1,
    opt_vega_hedge=opt2,
    broker_underlying=Broker(FixedBpsFee(1.0)),
    exec_underlying=ExecutionModel(half_spread=0.005),
    broker_option=Broker(FixedBpsFee(5.0)),
    exec_option=ExecutionModel(half_spread=0.02),
)

# DG seulement (gamma_ratio=1, vega_ratio=0)
df_DG = engine.run(
    S_path, T, rebalance_every=1,
    sigma_path=sigma_path,   # pricing/greeks suivent sigma(t)
    delta_ratio=1.0, gamma_ratio=1.0, vega_ratio=0.0
)

# DGV complet (gamma_ratio=1, vega_ratio=1)
df_DGV = engine.run(
    S_path, T, rebalance_every=1,
    sigma_path=sigma_path,
    delta_ratio=1.0, gamma_ratio=1.0, vega_ratio=1.0
)

print("DG net terminal:", float(df_DG["PnL_net"].iloc[-1]))
print("DGV net terminal:", float(df_DGV["PnL_net"].iloc[-1]))
print("DG costs:", float(df_DG["costs_cum"].iloc[-1]))
print("DGV costs:", float(df_DGV["costs_cum"].iloc[-1]))
# Out:
# DG net terminal: -0.0224163551129685
# DGV net terminal: 0.272246151774753
# DG costs: 0.022304553075418232
# DGV costs: 0.046598798195464634
